# %% [markdown]
# <a href="https://colab.research.google.com/github/mabitha-7/mlops_training/blob/main/TASK_9ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LOADING AND IMPORTING THE DATASET

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %% [markdown]
# SEE THE DIRECTORY

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %% [markdown]
# SEEING THE FIRST COLUMN

# %%
iris.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %% [markdown]
# CREATE A MODEL

# %%
from sklearn.linear_model import LogisticRegression
m=LogisticRegression()

# %% [markdown]
# IMPLEMENT THE TRAINA AND TEST

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(iris.data,iris.target,test_size=0.2)

# %% [markdown]
# HOW MUCHH DATA TO BE TAKEN AS TRAIN

# %%
len(x_train)
# Out:
# 120

# %% [markdown]
# HOW MUCH DATA TOBE TAKEN AS TEST

# %%
len(x_test)
# Out:
# 30

# %% [markdown]
# TRAIN THE MODEL

# %%
m.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# CHECKING THE SCORE

# %%
m.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# VIEWING THE MODEL PREDICTED ONE

# %%
m.predict(iris.data[0:5])
# Out:
# array([0, 0, 0, 0, 0])

# %% [markdown]
# MODEL PREDICTED OUTPUT

# %%
y=m.predict(x_test)
y
# Out:
# array([1, 2, 0, 0, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 0, 0, 1, 2, 1, 1, 2, 2,
#        1, 2, 2, 2, 0, 0, 0, 0])

# %% [markdown]
# IMPLEMENTING THE CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y)
cm
# Out:
# array([[ 8,  0,  0],
#        [ 0,  7,  0],
#        [ 0,  1, 14]])

# %% [markdown]
# VISUALIZING THE PREDICTED

# %%
import seaborn as sn
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
import joblib
joblib.dump(m,"MCLGR_joblib")
# Out:
# ['MCLGR_joblib']
